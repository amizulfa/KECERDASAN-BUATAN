# %%
class Guru:
    guru = None
    
    def __init__(self, name):
        self.name = name
        
    @staticmethod
    def find(name):
        for i in range(len(Guru.guru)):
            if Guru.guru[i].name == name:
                return i
        return -1
            
    def __repr__(self):
            return "Guru: " + self.name
        
class Kelas:
    kelas = None
    
    def __init__(self, name, size):
        self.name = name
        self.size = size
        
    @staticmethod
    def find(name):
        for i in range(len(Kelas.kelas)):
            if Kelas.kelas[i].name == name:
                return i
        return -1
            
    def __repr__(self):
        return "Kelas: " + self.name
        
class Mapel:
    mapel = None
    
    def __init__(self, code, status=False):
        self.code = code
        self.status = status
        
    @staticmethod
    def find(code):
        for i in range(len(Mapel.mapel)):
            if Mapel.mapel[i].code == code:
                return i
        return -1
            
    def __repr__(self):
        return "Mapel: " + self.code
            
class Ruang:
    ruang = None
    
    def __init__(self, name, size, status=True):
        self.name = name
        self.size = size
        self.status = status
        
    @staticmethod
    def find(name):
        for i in range(len(Ruang.ruang)):
            if Ruang.ruang[i].name == name:
                return i
        return -1
            
    def __repr__(self):
        return "Ruangan: " + self.name
        
class Jadwal:
    jadwal = None
    
    def __init__(self, mulai, selesai, hari, status_slot=False):
        self.mulai = mulai
        self.selesai = selesai
        self.hari = hari
        self.status_slot = status_slot
            
    def __repr__(self):
        return "Pukul: " + self.mulai + "-" + self.selesai + " Hari: " + self.hari

# %%
import random, copy
from math import ceil, log2
import math
import pandas as pd

# %%
Guru.guru = [Guru("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),
             Guru("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),
             Guru("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),
             Guru("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),
             Guru("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),
             Guru("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),
             Guru("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),
             Guru("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),
             Guru("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),
             Guru("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)")
            ]

Kelas.kelas = [Kelas("A", 40),
               Kelas("B", 40),
               Kelas("C", 40),
               Kelas("D", 40),
               Kelas("E", 40),
               Kelas("F", 40),
               Kelas("G", 40),
               Kelas("H", 40),
               Kelas("I", 40),
               Kelas("J", 40)
              ]

Mapel.mapel = [Mapel("PAI"),
               Mapel("PKn"),
               Mapel("Bahasa Indonesia"),
               Mapel("Matematika"),
               Mapel("IPA"),
               Mapel("IPS"),
               Mapel("Bahasa Inggris"),
               Mapel("SBK"),
               Mapel("PJOK"),
               Mapel("Prakarya")
              ]

Ruang.ruang = [Ruang("Lab-1", 40),
               Ruang("Lab-2", 40),
               Ruang("Lab-3", 40),
               Ruang("Lab-4", 40),
               Ruang("Lab-5", 40),
               Ruang("Lab-6", 40),
               Ruang("Lab-7", 40),
               Ruang("Lab-8", 40),
               Ruang("Lab-9", 40),
               Ruang("Lab-10", 40),
               Ruang("Lab-11", 40),
               Ruang("Lab-12", 40),
               Ruang("Lab-13", 40),
               Ruang("Lab-14", 40),
               Ruang("Lab-15", 40),
               Ruang("Lab-16", 40),
               Ruang("Lab-17", 40),
               Ruang("Lab-18", 40),
               Ruang("Lab-19", 40),
               Ruang("Lab-20", 40)
              ]

Jadwal.jadwal =[Jadwal("08:40","10:20","Senin"),
                Jadwal("10:20","12:00","Senin"),
                Jadwal("12:00","13:40","Senin"),
                Jadwal("07:00","08:40","Selasa"),
                Jadwal("08:40","10:20","Selasa"),
                Jadwal("10:20","12:00","Selasa"),
                Jadwal("07:00","08:40","Rabu"),
                Jadwal("08:40","10:20","Rabu"),
                Jadwal("10:20","12:00","Rabu"),
                Jadwal("07:00","08:40","Kamis"),
                Jadwal("08:40","10:20","Kamis"),
                Jadwal("10:20","12:00","Kamis"),
                Jadwal("07:00","08:40","Jumat"),
                Jadwal("08:40","10:20","Jumat"),
                Jadwal("10:20","12:00","Jumat")
              ]

# %%
max_score = None

cpg = []
lts = []
slots = []
bits_needed_backup_store = {}

def bits_needed(x):
    global bits_needed_backup_store
    r = bits_needed_backup_store.get(id(x))
    if r is None:
        r = int(ceil(log2(len(x))))
        bits_needed_backup_store[id(x)] = r
    return max(r, 1)
        
def join_cpg_pair(_cpg):
    res = []
    for i in range(0, len(_cpg), 3):
        res.append(_cpg[i] + _cpg[i + 1] + _cpg[i + 2])
    return res

def convert_input_to_bin():
    global cpg, lts, slots, max_score
    
    cpg = [ Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("A"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("A"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("A"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("A"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("A"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("A"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("A"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("A"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("A"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("A"),
             
            Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("B"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("B"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("B"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("B"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("B"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("B"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("B"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("B"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("B"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("B"), 
            
            Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("C"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("C"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("C"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("C"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("C"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("C"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("C"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("C"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("C"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("C"), 
            
            Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("D"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("D"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("D"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("D"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("D"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("D"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("D"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("D"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("D"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("D"), 
             
            Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("E"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("E"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("E"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("E"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("E"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("E"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("E"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("E"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("E"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("E"), 
            
            Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("F"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("F"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("F"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("F"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("F"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("F"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("F"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("F"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("F"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("F"), 
            
            Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("G"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("G"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("G"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("G"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("G"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("G"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("G"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("G"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("G"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("G"), 
            
            Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("H"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("H"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("H"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("H"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("H"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("H"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("H"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("H"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("H"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("H"), 
            
            Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("I"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("I"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("I"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("I"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("I"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("I"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("I"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("I"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("I"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("I"), 
            
            Mapel.find("PAI"),              Guru.find("Dr. Supriyanto, S.Pd(7) / Th. Puji Astuti, S.Pd(8) / Markhamah, S.Ag(9)"),                       Kelas.find("J"), 
            Mapel.find("PKn"),              Guru.find("Titik Murdiyani, S.Pd(7) / Tugas Widodo, S.Pd(8) / Achmad Haryadi Wiguna,. S.Pd(9)"),            Kelas.find("J"),  
            Mapel.find("Bahasa Indonesia"), Guru.find("Widyawati Palupi, M.Pd(7) / Esti Rumanti, S.Pd(8) / Dra. Ismayani Susana, M.Pd(9)"),             Kelas.find("J"),  
            Mapel.find("Matematika"),       Guru.find("MM.Kapti Widiowardani, S.Pd(7) / Endang Trisuwati, S.Pd(8) / Nur Hidayat Prayogo, ST(9)"),       Kelas.find("J"),
            Mapel.find("IPA"),              Guru.find("Dra. Anatri Endras Sumekar(7) / Ag. Bambang Triono(8) / Dra. Umi Naimatun. Farikha(9)"),         Kelas.find("J"),  
            Mapel.find("IPS"),              Guru.find("Dian Purnama Sari, ST., M.Pd(7) / Udy Mila Halliem Santoso, S.Psi(8) / Istiqomah, SE(9)"),       Kelas.find("J"), 
            Mapel.find("Bahasa Inggris"),   Guru.find("Supriyadi S,Pd(7) / Unifah Mawari, S.Pd(8) / Atik Yuniati, S.Pd(9)"),                            Kelas.find("J"),
            Mapel.find("SBK"),              Guru.find("Yusuf Winaryo, S.Pd(7) / Renggo Ayu Singgih P, S.Pd(8) / Dian Isnawati Warifah, SH(9)"),         Kelas.find("J"),
            Mapel.find("PJOK"),             Guru.find("Nanik Sri Hardini, S.Pd(7) / Sugiyanto, S.Pd(8) / Sri Ambar Arum, S.Pd(9)"),                     Kelas.find("J"),
            Mapel.find("Prakarya"),         Guru.find("Eko Yulianto, S.Pd, Si.(7) / Patmawati Ilyas Catur Pamungkas,S.Pd(8) / Amalia Anisa, S.Pd(9)"),  Kelas.find("J"),  
        ]
    
    for _c in range(len(cpg)):
        if _c % 3:
            cpg[_c] = (bin(cpg[_c])[2:]).rjust(bits_needed(Mapel.mapel), '0')
        elif _c % 3 == 1:
            cpg[_c] = (bin(cpg[_c])[2:]).rjust(bits_needed(Guru.guru), '0')
        else:
            cpg[_c] = (bin(cpg[_c])[2:]).rjust(bits_needed(Kelas.kelas), '0')
            
    cpg = join_cpg_pair(cpg)
    for r in range(len(Ruang.ruang)):
        lts.append((bin(r)[2:]).rjust(bits_needed(Ruang.ruang),'0'))
        
    for t in range(len(Jadwal.jadwal)):
        slots.append((bin(t)[2:]).rjust(bits_needed(Jadwal.jadwal),'0'))
        
    max_score = (len(cpg) - 1) * 3 + len(cpg) * 3

# %%
def course_bits(chromosome):
    i = 0
    
    return chromosome[i: i + bits_needed(Mapel.mapel)]

def guru_bits(chromosome):
    i = bits_needed(Mapel.mapel)
    
    return chromosome[i: i + bits_needed(Guru.guru)] 

def kelas_bits(chromosome):
    i = bits_needed(Mapel.mapel) + bits_needed(Mapel.mapel)
    
    return chromosome[i:i + bits_needed(Kelas.kelas)]

def slot_bits(chromosome):
    i = bits_needed(Mapel.mapel) + bits_needed(Guru.guru) + bits_needed(Kelas.kelas)
    
    return chromosome[i:i + bits_needed(Jadwal.jadwal)]

def lt_bits(chromosome):
    i = bits_needed(Mapel.mapel) + bits_needed(Guru.guru) + bits_needed(Kelas.kelas) + bits_needed(Jadwal.jadwal)
    
    return chromosome[i: i + bits_needed(Ruang.ruang)]

def slot_clash(a,b):
    if slot_bits(a) == slot_bits(b):
        return 1
    return 0

def faculty_member_one_class(chromosome):
    scores = 0
    for i in range(len(chromosome) - 1):
        clash = False
        for j in range(i + 1, len(chromosome)):
            if slot_clash(chromosome[i], chromosome[j]) and guru_bits(chromosome[i]) == guru_bits(chromosome[j]):
                clash = True
        if not clash:
            scores = scores + 1
    return scores

def kelas_member_one_class(chromosomes):
    scores = 0
    for i in range(len(chromosomes) - 1):
        clash = False
        for j in range(i + 1, len(chromosomes)):
            if slot_clash(chromosomes[i], chromosomes[j]) and kelas_bits(chromosomes[i]) == kelas_bits(chromosomes[j]):
                clash = True
                break
        if not clash:
            scores = scores + 1
    return scores

def use_spare_classroom(chromosome):
    scores = 0
    for i in range(len(chromosome) - 1):
        clash = False
        for j in range(i + 1, len(chromosome)):
            if slot_clash(chromosome[i], chromosome[j]) and lt_bits(chromosome[i]) == lt_bits(chromosome[j]):
                clash = True
        if not clash:
            scores = scores + 1
    return scores


def classroom_size(chromosomes):
    scores = 0
    for _c in chromosomes:
        if Kelas.kelas[int(kelas_bits(_c), 2)].size <= Ruang.ruang[int(lt_bits(_c), 2)].size:
            scores = scores + 1
    return scores

def clean_room(chromosomes):
    scores = 0
    for _c in chromosomes:
        if Ruang.ruang[int(lt_bits(_c), 2)].status:
            scores = scores + 1
    return scores

def appropriate_timeslot(chromosomes):
    scores = 0
    for _c in chromosomes:
        if Mapel.mapel[int(course_bits(_c), 2)].status == Jadwal.jadwal[int(slot_bits(_c), 2)].status_slot:
            scores = scores + 1
    return scores

# %%
def evaluate(chromosomes):
    global max_score
    score = 0
    score = score + use_spare_classroom(chromosomes)
    score = score + faculty_member_one_class(chromosomes)
    score = score + classroom_size(chromosomes)
    score = score + kelas_member_one_class(chromosomes)
    score = score + clean_room(chromosomes)
    score = score + appropriate_timeslot(chromosomes)
    return score / max_score

def cost(solution):
    return 1 / float(evaluate(solution))

def init_population(n):
    global cpg, lts, slots
    chromosomes = []
    for _n in range(n):
        chromosome = []
        for _c in cpg:
            chromosome.append(_c + random.choice(slots) + random.choice(lts))
        chromosomes.append(chromosome)
    return chromosomes

def mutate(chromosome):
    
    rand_slot = random.choice(slots)
    rand_lt = random.choice(lts)
    
    a = random.randint(0, len(chromosome) - 1)
    
    chromosome[a] = course_bits(chromosome[a]) + guru_bits(chromosome[a]) + kelas_bits(chromosome[a]) +rand_slot + rand_lt
    
def crossover(population):
    a = random.randint(0, len(population) - 1)
    b = random.randint(0, len(population) - 1)
    cut = random.randint(0, len(population[0]))
    population.append(population[a][:cut] + population[b][cut:])
    
def selection(population, n):
    population.sort(key=evaluate, reverse=True)
    while len(population) > n:
        population.pop()
        
def print_chromosome(chromosome):
    print(Jadwal.jadwal[int(slot_bits(chromosome), 2)], "|",
          Kelas.kelas[int(kelas_bits(chromosome), 2)], "|",
          Guru.guru[int(guru_bits(chromosome), 2)]
         )
    
def ssn(solution):
    rand_slot = random.choice(slots)
    rand_lt = random.choice(lts)
    
    a = random.randint(0, len(solution) - 1)
    
    new_solution = copy.deepcopy(solution)
    new_solution[a] = course_bits(solution[a]) + guru_bits(solution[a]) + kelas_bits(solution[a]) + rand_slot + lt_bits(solution[a]) + rand_lt 
    return [new_solution]
    
def swn(solution):
    a = random.randint(0, len(solution) - 1)
    b = random.randint(0, len(solution) - 1)
    new_solution = copy.deepcopy(solution)
    temp = slot_bits(solution[a])
    new_solution[a] = course_bits(solution[a]) + guru_bits(solution[a]) + kelas_bits(solution[a]) + slot_bits(solution[b]) + lt_bits(solution[a])
    
    new_solution[b] = course_bits(solution[b]) + guru_bits(solution[b]) + kelas_bits(solution[b]) + temp + lt_bits(solution[b])
    return [new_solution]

def acceptance_probability(old_cost, new_cost, temperature):
    if new_cost < old_cost:
        return 1.0
    else:
        return math.exp((old_cost - new_cost) / temperature)

def simulated_annealing():
    alpha = 0.9
    T = 1.0
    T_min = 0.00001
    
    convert_input_to_bin()
    population = init_population(1)
    old_cost = cost(population[0])
    
    for __n in range(500):
        new_solution = swn(population[0])
        new_solution = ssn(population[0])
        new_cost = cost(new_solution[0])
        ap = acceptance_probability(old_cost, new_cost, T)
        if ap > random.random():
            population = new_solution
            old_cost = new_cost
        T = T * alpha
    print("-------------------Jadwal Pelajaran--------------------")
    for lec in population[0]:
        print_chromosome(lec)
    print("Score: ", evaluate(population[0]))
    
def genetic_algoritma():
    generation = 0
    convert_input_to_bin()
    population = init_population(3)
    
    print("---------------Algoritma Genetika------------")
    while True:
        if evaluate(max(population, key=evaluate)) == 1 or generation == 500:
            print("Generations: ", generation)
            print("nilai fitnes chromosome terbaik", evaluate(max(population, key=evaluate)))
            print("chromosome terbaik: ", max(population, key=evaluate))
            for lec in max(population, key=evaluate):
                print_chromosome(lec)
            break
        else:
            for _c in range(len(population)):
                crossover(population)
                selection(population, 10)
                mutate(population[_c])
        generation = generation + 1
            
def main():
    random.seed()
    genetic_algoritma()
    simulated_annealing()
main()
# Out:
# ---------------Algoritma Genetika------------
# Generations:  300
# nilai fitnes chromosome terbaik 1.0
# ...
